# %% [markdown]
# <b>Importing Geospatial Libraries</b>

# %%
import geopandas as gpd

# %% [markdown]
# <b>Reading Vector Data</b>

# %%
gdf1=gpd.read_file("/Users/eliekhveh/Desktop/py_scripts/vector/data/municipality.json")
gdf1.head(5)
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM          Nepali  Shape_Leng  \
# 0  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी    0.430900
# 1  101      2   61.067429   137.848122  10102        मैवाखोला    0.577692
# 2  101      3   75.987469   210.313039  10103        मेरिङदेन    0.718499
# 3  101      4  123.175400   442.960328  10104      मिक्वाखोला    1.164097
# 4  101      5  228.107830  1858.441119  10105       फक्ताङलुङ    2.186142
#
#    Shape_Area                                           geometry
# ...

# %%
gdf2=gpd.read_file("/Users/eliekhveh/Desktop/py_scripts/vector/data/municipality.shp")
gdf2.head(5)
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
#metadata
print(gdf1.crs)
print(gdf1.geom_type)
# Out:
# epsg:4326
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 769    Polygon
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# Length: 774, dtype: object

# %% [markdown]
# <b>Visualization of Vector Data</b>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots(1, figsize=(6,10))
gdf1.plot(ax=ax, column="Province",legend=True)
leg=ax.get_legend()
leg.set_bbox_to_anchor((1.04,.5))

# %% [markdown]
# <b>Writing Data</b>

# %%
gdf1.to_file("/Users/eliekhveh/Desktop/py_scripts/vector/output/out_shp.shp")
gdf1.to_file("/Users/eliekhveh/Desktop/py_scripts/vector/output/out_geojson.geojson", driver='GeoJSON')
gdf1.to_file("/Users/eliekhveh/Desktop/py_scripts/vector/output/out_geopackage.gpkg", layer="m", driver='GPKG', encoding='utf-8')
# Out:
# /Users/eliekhveh/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /Users/eliekhveh/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /Users/eliekhveh/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
